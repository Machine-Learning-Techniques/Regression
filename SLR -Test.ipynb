# %% [markdown]
# Importing the libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[: , :-1].values
y = dataset.iloc[: , -1].values

# %% [markdown]
# Splitting the dataset into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %% [markdown]
# Training the Simple Linear Regresson model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predicting the results based on the test set

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# Predicting the salary for a specific guy with 12Ys experience

# %%
y_pred12 = regressor.predict([[12]])
int(y_pred12)
# Out:
# 138967

# %% [markdown]
# Showing y-Intercept and Variable Coefficient of regrresor

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 26816.19224403119
# [9345.94244312]

# %% [markdown]
# Visualising the trained regressor and the train set

# %%
plt.scatter(X_train, y_train, c='red')
plt.plot(X_train, regressor.predict(X_train), c='blue')
plt.title('Simple Linear Regression - Train set')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Visualising the regressor prediction on the test set

# %%
plt.scatter(X_test, y_test, c='red')
plt.plot(X_train, regressor.predict(X_train), c='blue')
plt.title('Simple Linear Regression - Test set')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
